# %% [markdown]
# # Packages

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv("/content/carbon_emissions_by_distance.csv")
df
# Out:
#      Unnamed: 0  distance (km)  car (kg CO2)  bus (kg CO2)  motorbike (kg CO2)
# 0             0       0.000000      0.000000      0.000000            0.000000
# 1             1       1.000000      0.163900      0.102200            0.102200
# 2             2       0.250000      0.040975      0.025550            0.025550
# 3             3       0.600000      0.098340      0.061320            0.061320
# 4             4       0.800000      0.131120      0.081760            0.081760
# ..          ...            ...           ...           ...                 ...
# 995         995     124.375000     20.385063     12.711125           12.711125
# 996         996     166.000000     27.207400     16.965200           16.965200
# 997         997     997.000000    163.408300    101.893400          101.893400
# 998         998     142.571429     23.367457     14.570800           14.570800
# 999         999     124.875000     20.467012     12.762225           12.762225
#
# [1000 rows x 5 columns]

# %% [markdown]
# # Train

# %%
X = df[['distance (km)']]
y_car = df['car (kg CO2)']

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_train_scaled, y_car, test_size=0.3, random_state=42)

model_carbon_car = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1)
])

model_carbon_car.compile(optimizer='adam',
              loss='mean_squared_error')

history = model_carbon_car.fit(X_train,
                    y_train,
                    epochs=100,
                    batch_size=32,
                    validation_data=(X_test, y_test))

loss = model_carbon_car.evaluate(X_test, y_test)
print(f"loss: {loss}")
# Out:
# Epoch 1/100
# 22/22 [==============================] - 1s 12ms/step - loss: 1834.9854 - val_loss: 1710.2926
# Epoch 2/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1804.6820 - val_loss: 1665.4972
# Epoch 3/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1728.1311 - val_loss: 1561.0677
# Epoch 4/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1572.1783 - val_loss: 1342.1738
# Epoch 5/100
# 22/22 [==============================] - 0s 5ms/step - loss: 1280.1202 - val_loss: 1004.8427
# Epoch 6/100
# 22/22 [==============================] - 0s 6ms/step - loss: 866.4705 - val_loss: 577.4668
# Epoch 7/100
# 22/22 [==============================] - 0s 6ms/step - loss: 415.9799 - val_loss: 202.1091
# Epoch 8/100
# 22/22 [==============================] - 0s 6ms/step - loss: 113.6059 - val_loss: 25.5755
# Epoch 9/100
# 22/22 [==============================] - 0s 6ms/step - loss: 10.1992 - val_loss: 2.3418
# Epoch 10/100
# ...

# %%
model_carbon_car.save("model_carbon_car.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
X = df[['distance (km)']]
y_car = df['bus (kg CO2)']

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_train_scaled, y_car, test_size=0.3, random_state=42)

model_carbon_bus = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1)
])

model_carbon_bus.compile(optimizer='adam',
              loss='mean_squared_error')

history = model_carbon_bus.fit(X_train,
                    y_train,
                    epochs=100,
                    batch_size=32,
                    validation_data=(X_test, y_test))

loss = model_carbon_bus.evaluate(X_test, y_test)
print(f"loss: {loss}")
# Out:
# Epoch 1/100
# 22/22 [==============================] - 1s 10ms/step - loss: 701.8564 - val_loss: 645.7258
# Epoch 2/100
# 22/22 [==============================] - 0s 4ms/step - loss: 669.0117 - val_loss: 602.5558
# Epoch 3/100
# 22/22 [==============================] - 0s 3ms/step - loss: 595.8889 - val_loss: 502.9404
# Epoch 4/100
# 22/22 [==============================] - 0s 5ms/step - loss: 446.1220 - val_loss: 319.6648
# Epoch 5/100
# 22/22 [==============================] - 0s 3ms/step - loss: 242.5446 - val_loss: 114.8957
# Epoch 6/100
# 22/22 [==============================] - 0s 4ms/step - loss: 56.0525 - val_loss: 12.6499
# Epoch 7/100
# 22/22 [==============================] - 0s 4ms/step - loss: 5.9850 - val_loss: 3.0900
# Epoch 8/100
# 22/22 [==============================] - 0s 4ms/step - loss: 2.7603 - val_loss: 2.2851
# Epoch 9/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.8891 - val_loss: 1.5561
# Epoch 10/100
# ...

# %%
model_carbon_bus.save("model_carbon_bus.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
X = df[['distance (km)']]
y_car = df['motorbike (kg CO2)']

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_train_scaled, y_car, test_size=0.3, random_state=42)

model_carbon_motorbike = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1)
])

model_carbon_motorbike.compile(optimizer='adam',
              loss='mean_squared_error')

history = model_carbon_motorbike.fit(X_train,
                    y_train,
                    epochs=100,
                    batch_size=32,
                    validation_data=(X_test, y_test))

loss = model_carbon_motorbike.evaluate(X_test, y_test)
print(f"loss: {loss}")
# Out:
# Epoch 1/100
# 22/22 [==============================] - 1s 9ms/step - loss: 715.8990 - val_loss: 659.3795
# Epoch 2/100
# 22/22 [==============================] - 0s 3ms/step - loss: 687.0883 - val_loss: 625.6600
# Epoch 3/100
# 22/22 [==============================] - 0s 3ms/step - loss: 639.7294 - val_loss: 562.9880
# Epoch 4/100
# 22/22 [==============================] - 0s 4ms/step - loss: 551.5420 - val_loss: 452.8009
# Epoch 5/100
# 22/22 [==============================] - 0s 4ms/step - loss: 406.4793 - val_loss: 284.8722
# Epoch 6/100
# 22/22 [==============================] - 0s 4ms/step - loss: 206.1382 - val_loss: 101.7875
# Epoch 7/100
# 22/22 [==============================] - 0s 4ms/step - loss: 46.0255 - val_loss: 5.3066
# Epoch 8/100
# 22/22 [==============================] - 0s 4ms/step - loss: 2.0258 - val_loss: 1.4689
# Epoch 9/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.0554 - val_loss: 0.8570
# Epoch 10/100
# ...

# %%
model_carbon_motorbike.save("model_carbon_motorbike.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
